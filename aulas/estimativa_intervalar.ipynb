# %%
# Estimativa intervalndas as pdar

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt        
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 # Estimativa intervalndas as pdar
#       2
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Estimativa intervalndas as pdar

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt        
import statsmodels.api as sm


tempo_escola = np.array([15,20,20,40,50,25,10,55,35,30])
distancia = np.array([8,6,15,20,25,11,5,32,28,20])

plt.scatter(tempo_escola, distancia)
plt.title("Grafico de dispersão")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 tempo_escola = np.array([15,20,20,40,50,25,10,55,35,30])
#       2 distancia = np.array([8,6,15,20,25,11,5,32,28,20])
#       3
# ----> 4 plt.scatter(tempo_escola, distancia)
#       5 plt.title("Grafico de dispersão")
#       6 plt.show()
#
# NameError: name 'plt' is not defined
